# %% [markdown]
# <a href="https://colab.research.google.com/github/HernandezDylan/UIII-Act-3-listas-con-funciones-Psicologo-Hernadez-Dylan-1245/blob/main/UIII_Act_3_listas_con_funciones_Hernadez_Dylan_1245.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Hernadez Dylan NL = 24 Fecha 11/05/2026
# #### Psicologo

# %%
class Psicologo:
    def __init__(self, nombre, telefono, edad):
        self.nombre = nombre
        self.telefono = telefono
        self.edad = edad

    def datos(self):
        print(self.nombre, self.telefono, self.edad)

    def escuchar(self, paciente):
        print(self.nombre, "escucha a", paciente)

    def diagnosticar(self, paciente):
        print(self.nombre, "diagnostica a", paciente)

    def terapia(self, paciente):
        print(paciente, "recibe terapia")

print("=== Psicologo ===")

doctor = Psicologo(
    input("Nombre: "),
    input("Teléfono: "),
    input("Edad: ")
)

while True:

    print("\n1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir")
    op = input("Opción: ")

    if op == "1":
        doctor.datos()

    elif op == "2":
        doctor.escuchar(input("Paciente: "))

    elif op == "3":
        doctor.diagnosticar(input("Paciente: "))

    elif op == "4":
        doctor.terapia(input("Paciente: "))

    elif op == "5":
        print("Programa realizado por Hernandez Dylan 1245")
        break

    else:
        print("Error")
# Out:
# === Psicologo ===
# Nombre: Dylan
# Teléfono: 6563483374
# Edad: 33
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 1
# Dylan  6563483374 33
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 2
# Paciente: Rafael
# Dylan  escucha a Rafael
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 2
# Paciente: Luis
# Dylan  escucha a Luis
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 3
# Paciente: Adrian
# Dylan  diagnostica a Adrian
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 3
# Paciente: Alonso
# Dylan  diagnostica a Alonso
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 4
# Paciente: Alberto
# Alberto recibe terapia
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 4
# Paciente: Jesus
# Jesus  recibe terapia
#
# 1.Datos 2.Escuchar 3.Diagnosticar 4.Terapia 5.Salir
# Opción: 5
# Programa realizado por Hernandez Dylan 1245

# %% [markdown]
# <img src="https://raw.githubusercontent.com/HernandezDylan/UIII-Act-3-listas-con-funciones-Psicologo-Hernadez-Dylan-1245/refs/heads/main/UIII%20Act%203%20listas%20con%20funciones%20Psicologo.png" witdh="500" height="400" alt="Texto descriptivo">
